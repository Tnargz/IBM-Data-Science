# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Grant Miller</b>
# <b>Business Analyst</b>

# %% [markdown]
# <i>I am interested in data science to continue my education, improve my skillset, and further my career.</i>

# %% [markdown]
# ### The code below is suppose to add one plus one with output being 2

# %%
1+1
# Out:
# 2

# %% [markdown]
# <strike>strike text example</strike>
# <blockquote>blockquote example</blockquote>
# [link to github](https://github.com/)
